# %%
import os
import pandas as pd

# %%
category = 'Games'

signal = 'like'

num_candidates = 20

candidates_path = '/sise/bshapira-group/lilachzi/models/LlamaRec/data/preprocessed'
candidates_path = os.path.join(candidates_path, f'ciao_{category}_{signal}')

# %% [markdown]
# **Validation candidates**

# %%
val_cands = pd.read_csv(os.path.join(candidates_path, f'valid_{num_candidates}_candidates.csv'))

# %%
val_cands
# Out:
#        product_id  voter_id  \
# 0              42      2628
# 1              42      5618
# 2              42     13861
# 3              42     19606
# 4              42   5017281
# ...           ...       ...
# 15824      107608   5013856
# 15825      107608   5021102
# 15826      107608   5027154
# 15827      107608   5030710
# 15828      107608   5085480
#
#                                               candidates  \
# 0      {239042: 0.0, 283455: 0.0, 300170: 0.0, 279954...
# 1      {279954: 4.0, 300170: 0.0, 239042: 0.0, 283455...
# 2      {283455: 2.0, 300170: 3.5, 279909: 3.5, 279954...
# 3      {239042: 0.0, 283455: 0.0, 300170: 0.0, 279909...
# 4      {279954: 4.0, 239042: 0.0, 283455: 0.0, 300170...
# ...                                                  ...
# 15824  {271907: 4.0, 262210: 0.0, 272198: 0.0, 252772...
# 15825  {272198: 0.0, 296881: 0.0, 271907: 0.0, 272624...
# 15826  {272198: 4.0, 239055: 0.0, 296881: 0.0, 298667...
# ...
